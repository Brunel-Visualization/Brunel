// %%
import org.apache.spark.sql.DataFrame

// %%
val seq = (0 until 3).map(i => (i, i)).toSeq
val df = spark.sqlContext.createDataFrame(seq)
// Out:
// seq = Vector((0,0), (1,1), (2,2))
// df = [_1: int, _2: int]
// [_1: int, _2: int]

// %%
%%brunel data('df') x(_1) y(_2) bar  style("fill:red") filter(_1:2) :: width=300, height=300
// Out:
//                 'topojson' : '//cdnjs.cloudflare.com/aja...
//          <link rel="stylesheet" type="text/css" href="https://brunelvis.org/js/brunel.2.5.css" charset="utf-8">
//          <link rel="stylesheet" type="text/css" href="https://brunelvis.org/js/sumoselect.css" charset="utf-8">
//          <style> #visid50df6154-01d2-4ae9-a021-17e319742369.brunel .chart1 .element1 .element {
// 	fill: red;
// } </style>
//          <div id="controlsIda6f2302d-485f-4c80-9bdc-c189e4f8731e" class="brunel"/>
// <svg id="visid50df6154-01d2-4ae9-a021-17e319742369" width="300" height="300"></svg>
//
// <script>
// require.config({
//             waitSeconds: 60,
//             paths: {
//                 'd3': '//cdnjs.cloudflare.com/ajax/libs/d3/4.2.1/d3.min',
//                 'topojson' : '//cdnjs.cloudflare.com/ajax/libs/topojson/1.6.20/topojson.min',
//                 'brunel' : 'https://brunelvis.org/js/brunel.2.5.min',
//                 'brunelControls' : 'https://brunelvis.org/js/brunel.controls.2.5.min'
//             },
//
//             shim: {
//                'brunel' : {
//                     exports: 'BrunelD3',
//                     deps: ['d3', 'topojson'],
//                     init: function() {
//                        return {
//                          BrunelD3 : BrunelD3,
//                          BrunelData : BrunelData
//                       }
//                     }
//                 },
//                'brunelControls' : {
//                     exports: 'BrunelEventHandlers',
//                     init: function() {
//                        return {
//                          BrunelEventHandlers: BrunelEventHandlers,
//                          BrunelJQueryControlFactory: BrunelJQueryControlFactory
//                       }
//                     }
//                 }
//
//             }
//
//         });
//
//         require(["d3"], function(d3) {
//         require(["brunel", "brunelControls"], function(brunel, brunelControls) {
//
//             function  BrunelVis(visId) {
//   "use strict";                                                                       // strict mode
//   var datasets = [],                                      // array of datasets for the original data
//       pre = function(d, i) { return d },                         // default pre-process does nothing
//       post = function(d, i) { return d },                       // default post-process does nothing
//       transitionTime = 200,                                        // transition time for animations
//       charts = [],                                                       // the charts in the system
//       vis = d3.select('#' + visId).attr('class', 'brunel');                     // the SVG container
//
//   BrunelD3.addDefinitions(vis);                                   // ensure standard symbols present
//
//   // Define chart #1 in the visualization //////////////////////////////////////////////////////////
//
//   charts[0] = function(parentNode, filterRows) {
//     var geom = BrunelD3.geometry(parentNode || vis.node(), 0, 0, 1, 1, 5, 47, 37, 15),
//       elements = [];                                              // array of elements in this chart
//
//     // Define groups for the chart parts ///////////////////////////////////////////////////////////
//
//     var chart =  vis.append('g').attr('class', 'chart1')
//       .attr('transform','translate(' + geom.chart_left + ',' + geom.chart_top + ')');
//     var overlay = chart.append('g').attr('class', 'element').attr('class', 'overlay');
//     var zoom = d3.zoom().scaleExtent([1/3,3]);
//     var zoomNode = overlay.append('rect').attr('class', 'overlay')
//       .attr('x', geom.inner_left).attr('y', geom.inner_top)
//       .attr('width', geom.inner_rawWidth).attr('height', geom.inner_rawHeight)
//       .style('cursor', 'move').call(zoom)
//       .node();
//     zoomNode.__zoom = d3.zoomIdentity;
//     chart.append('rect').attr('class', 'background').attr('width', geom.chart_right-geom.chart_left).attr('height', geom.chart_bottom-geom.chart_top);
//     var interior = chart.append('g').attr('class', 'interior zoomNone')
//       .attr('transform','translate(' + geom.inner_left + ',' + geom.inner_top + ')')
//       .attr('clip-path', 'url(#clip_visid50df6154-01d2-4ae9-a021-17e319742369_chart1_inner)');
//     interior.append('rect').attr('class', 'inner').attr('width', geom.inner_width).attr('height', geom.inner_height);
//     var gridGroup = interior.append('g').attr('class', 'grid');
//     var axes = chart.append('g').attr('class', 'axis')
//       .attr('transform','translate(' + geom.inner_left + ',' + geom.inner_top + ')');
//     vis.select('defs').append('clipPath').attr('id', 'clip_visid50df6154-01d2-4ae9-a021-17e319742369_chart1_inner').append('rect')
//       .attr('x', 0).attr('y', 0)
//       .attr('width', geom.inner_rawWidth+1).attr('height', geom.inner_rawHeight+1);
//
//     // Scales //////////////////////////////////////////////////////////////////////////////////////
//
//     var scale_x = d3.scaleLinear().domain([-0.5, 2.5000003])
//       .range([0, geom.inner_width]);
//     var scale_inner = d3.scaleLinear().domain([0,1])
//       .range([-0.5, 0.5]);
//     var scale_y = d3.scaleLinear().domain([0, 2.2000002])
//       .range([geom.inner_height, 0]);
//     var base_scales = [scale_x, scale_y];                           // untransformed original scales
//
//     // Axes ////////////////////////////////////////////////////////////////////////////////////////
//
//     axes.append('g').attr('class', 'x axis')
//       .attr('transform','translate(0,' + geom.inner_rawHeight + ')')
//       .attr('clip-path', 'url(#clip_visid50df6154-01d2-4ae9-a021-17e319742369_chart1_haxis)');
//     vis.select('defs').append('clipPath').attr('id', 'clip_visid50df6154-01d2-4ae9-a021-17e319742369_chart1_haxis').append('polyline')
//       .attr('points', '-1,-1000, -1,-1 -5,5, -1000,5, -100,1000, 10000,1000 10000,-1000');
//     axes.select('g.axis.x').append('text').attr('class', 'title').text('_1').style('text-anchor', 'middle')
//       .attr('x',geom.inner_rawWidth/2)
//       .attr('y', geom.inner_bottom - 2.0).attr('dy','-0.27em');
//     axes.append('g').attr('class', 'y axis')
//       .attr('clip-path', 'url(#clip_visid50df6154-01d2-4ae9-a021-17e319742369_chart1_vaxis)');
//     vis.select('defs').append('clipPath').attr('id', 'clip_visid50df6154-01d2-4ae9-a021-17e319742369_chart1_vaxis').append('polyline')
//       .attr('points', '-1000,-10000, 10000,-10000, 10000,' + (geom.inner_rawHeight+1) + ', -1,' + (geom.inner_rawHeight+1) + ', -1,' + (geom.inner_rawHeight+5) + ', -1000,' + (geom.inner_rawHeight+5) );
//     axes.select('g.axis.y').append('text').attr('class', 'title').text('_2').style('text-anchor', 'middle')
//       .attr('x',-geom.inner_rawHeight/2)
//       .attr('y', 4-geom.inner_left).attr('dy', '0.7em').attr('transform', 'rotate(270)');
//
//     var axis_bottom = d3.axisBottom(scale_x).ticks(6);
//     var axis_left = d3.axisLeft(scale_y).ticks(Math.min(10, Math.round(geom.inner_rawHeight / 20)));
//
//     function buildAxes(time) {
//       var axis_x = axes.select('g.axis.x');
//       BrunelD3.transition(axis_x, time).call(axis_bottom.scale(scale_x));
//       var axis_y = axes.select('g.axis.y');
//       BrunelD3.transition(axis_y, time).call(axis_left.scale(scale_y));
//     }
//     zoom.on('zoom', function(t, time) {
//         t = t ||BrunelD3.restrictZoom(d3.event.transform, geom, this);
//         scale_x = t.rescaleX(base_scales[0]);
//         scale_y = t.rescaleY(base_scales[1]);
//         zoomNode.__zoom = t;
//         interior.attr('class', 'interior ' + BrunelD3.zoomLabel(t.k));;
//         build(time || -1);
//     });
//
//     // Define element #1 ///////////////////////////////////////////////////////////////////////////
//
//     elements[0] = function() {
//       var original, processed,                           // data sets passed in and then transformed
//         element, data,                                 // brunel element information and brunel data
//         selection, merged;                                      // d3 selection and merged selection
//       var elementGroup = interior.append('g').attr('class', 'element1'),
//         main = elementGroup.append('g').attr('class', 'main'),
//         labels = BrunelD3.undoTransform(elementGroup.ap

// %%
%%brunel data('df') x(_1) y(_2) point   filter(_2, _1) :: width=300, height=300
// Out:
//                 'brunel' : 'https://brunelvis.org/js/...
//          <link rel="stylesheet" type="text/css" href="https://brunelvis.org/js/brunel.2.5.css" charset="utf-8">
//          <link rel="stylesheet" type="text/css" href="https://brunelvis.org/js/sumoselect.css" charset="utf-8">
//          <style>  </style>
//          <div id="controlsIdbb6bd7d1-3d60-4cc3-8257-5a90092806f7" class="brunel"/>
// <svg id="visidccb5006a-876f-4466-b0e0-1dc35db8c668" width="300" height="300"></svg>
//
// <script>
// require.config({
//             waitSeconds: 60,
//             paths: {
//                 'd3': '//cdnjs.cloudflare.com/ajax/libs/d3/4.2.1/d3.min',
//                 'topojson' : '//cdnjs.cloudflare.com/ajax/libs/topojson/1.6.20/topojson.min',
//                 'brunel' : 'https://brunelvis.org/js/brunel.2.5.min',
//                 'brunelControls' : 'https://brunelvis.org/js/brunel.controls.2.5.min'
//             },
//
//             shim: {
//                'brunel' : {
//                     exports: 'BrunelD3',
//                     deps: ['d3', 'topojson'],
//                     init: function() {
//                        return {
//                          BrunelD3 : BrunelD3,
//                          BrunelData : BrunelData
//                       }
//                     }
//                 },
//                'brunelControls' : {
//                     exports: 'BrunelEventHandlers',
//                     init: function() {
//                        return {
//                          BrunelEventHandlers: BrunelEventHandlers,
//                          BrunelJQueryControlFactory: BrunelJQueryControlFactory
//                       }
//                     }
//                 }
//
//             }
//
//         });
//
//         require(["d3"], function(d3) {
//         require(["brunel", "brunelControls"], function(brunel, brunelControls) {
//
//             function  BrunelVis(visId) {
//   "use strict";                                                                       // strict mode
//   var datasets = [],                                      // array of datasets for the original data
//       pre = function(d, i) { return d },                         // default pre-process does nothing
//       post = function(d, i) { return d },                       // default post-process does nothing
//       transitionTime = 200,                                        // transition time for animations
//       charts = [],                                                       // the charts in the system
//       vis = d3.select('#' + visId).attr('class', 'brunel');                     // the SVG container
//
//   BrunelD3.addDefinitions(vis);                                   // ensure standard symbols present
//
//   // Define chart #1 in the visualization //////////////////////////////////////////////////////////
//
//   charts[0] = function(parentNode, filterRows) {
//     var geom = BrunelD3.geometry(parentNode || vis.node(), 0, 0, 1, 1, 5, 47, 37, 15),
//       elements = [];                                              // array of elements in this chart
//
//     // Define groups for the chart parts ///////////////////////////////////////////////////////////
//
//     var chart =  vis.append('g').attr('class', 'chart1')
//       .attr('transform','translate(' + geom.chart_left + ',' + geom.chart_top + ')');
//     var overlay = chart.append('g').attr('class', 'element').attr('class', 'overlay');
//     var zoom = d3.zoom().scaleExtent([1/3,3]);
//     var zoomNode = overlay.append('rect').attr('class', 'overlay')
//       .attr('x', geom.inner_left).attr('y', geom.inner_top)
//       .attr('width', geom.inner_rawWidth).attr('height', geom.inner_rawHeight)
//       .style('cursor', 'move').call(zoom)
//       .node();
//     zoomNode.__zoom = d3.zoomIdentity;
//     chart.append('rect').attr('class', 'background').attr('width', geom.chart_right-geom.chart_left).attr('height', geom.chart_bottom-geom.chart_top);
//     var interior = chart.append('g').attr('class', 'interior zoomNone')
//       .attr('transform','translate(' + geom.inner_left + ',' + geom.inner_top + ')')
//       .attr('clip-path', 'url(#clip_visidccb5006a-876f-4466-b0e0-1dc35db8c668_chart1_inner)');
//     interior.append('rect').attr('class', 'inner').attr('width', geom.inner_width).attr('height', geom.inner_height);
//     var gridGroup = interior.append('g').attr('class', 'grid');
//     var axes = chart.append('g').attr('class', 'axis')
//       .attr('transform','translate(' + geom.inner_left + ',' + geom.inner_top + ')');
//     vis.select('defs').append('clipPath').attr('id', 'clip_visidccb5006a-876f-4466-b0e0-1dc35db8c668_chart1_inner').append('rect')
//       .attr('x', 0).attr('y', 0)
//       .attr('width', geom.inner_rawWidth+1).attr('height', geom.inner_rawHeight+1);
//
//     // Scales //////////////////////////////////////////////////////////////////////////////////////
//
//     var scale_x = d3.scaleLinear().domain([-0.5, 2.5000003])
//       .range([0, geom.inner_width]);
//     var scale_inner = d3.scaleLinear().domain([0,1])
//       .range([-0.5, 0.5]);
//     var scale_y = d3.scaleLinear().domain([-0.5, 2.5000003])
//       .range([geom.inner_height, 0]);
//     var base_scales = [scale_x, scale_y];                           // untransformed original scales
//
//     // Axes ////////////////////////////////////////////////////////////////////////////////////////
//
//     axes.append('g').attr('class', 'x axis')
//       .attr('transform','translate(0,' + geom.inner_rawHeight + ')')
//       .attr('clip-path', 'url(#clip_visidccb5006a-876f-4466-b0e0-1dc35db8c668_chart1_haxis)');
//     vis.select('defs').append('clipPath').attr('id', 'clip_visidccb5006a-876f-4466-b0e0-1dc35db8c668_chart1_haxis').append('polyline')
//       .attr('points', '-1,-1000, -1,-1 -5,5, -1000,5, -100,1000, 10000,1000 10000,-1000');
//     axes.select('g.axis.x').append('text').attr('class', 'title').text('_1').style('text-anchor', 'middle')
//       .attr('x',geom.inner_rawWidth/2)
//       .attr('y', geom.inner_bottom - 2.0).attr('dy','-0.27em');
//     axes.append('g').attr('class', 'y axis')
//       .attr('clip-path', 'url(#clip_visidccb5006a-876f-4466-b0e0-1dc35db8c668_chart1_vaxis)');
//     vis.select('defs').append('clipPath').attr('id', 'clip_visidccb5006a-876f-4466-b0e0-1dc35db8c668_chart1_vaxis').append('polyline')
//       .attr('points', '-1000,-10000, 10000,-10000, 10000,' + (geom.inner_rawHeight+1) + ', -1,' + (geom.inner_rawHeight+1) + ', -1,' + (geom.inner_rawHeight+5) + ', -1000,' + (geom.inner_rawHeight+5) );
//     axes.select('g.axis.y').append('text').attr('class', 'title').text('_2').style('text-anchor', 'middle')
//       .attr('x',-geom.inner_rawHeight/2)
//       .attr('y', 4-geom.inner_left).attr('dy', '0.7em').attr('transform', 'rotate(270)');
//
//     var axis_bottom = d3.axisBottom(scale_x).ticks(6);
//     var axis_left = d3.axisLeft(scale_y).ticks(Math.min(10, Math.round(geom.inner_rawHeight / 20)));
//
//     function buildAxes(time) {
//       var axis_x = axes.select('g.axis.x');
//       BrunelD3.transition(axis_x, time).call(axis_bottom.scale(scale_x));
//       var axis_y = axes.select('g.axis.y');
//       BrunelD3.transition(axis_y, time).call(axis_left.scale(scale_y));
//     }
//     zoom.on('zoom', function(t, time) {
//         t = t ||BrunelD3.restrictZoom(d3.event.transform, geom, this);
//         scale_x = t.rescaleX(base_scales[0]);
//         scale_y = t.rescaleY(base_scales[1]);
//         zoomNode.__zoom = t;
//         interior.attr('class', 'interior ' + BrunelD3.zoomLabel(t.k));;
//         build(time || -1);
//     });
//
//     // Define element #1 ///////////////////////////////////////////////////////////////////////////
//
//     elements[0] = function() {
//       var original, processed,                           // data sets passed in and then transformed
//         element, data,                                 // brunel element information and brunel data
//         selection, merged;                                      // d3 selection and merged selection
//       var elementGroup = interior.append('g').attr('class', 'element1'),
//         main = elementGroup.append('g').attr('class', 'main'),
//         labels = BrunelD3.undoTransform(elementGroup.append('g').attr('class', 'labels').attr('aria-hidden', 'true'), elementGroup);
//
//       func

// %%
%%brunel  map('uk','france','spain','germany')
// Out:
//                 'brunel' : 'https://brunelvis.org/js/...
//          <link rel="stylesheet" type="text/css" href="https://brunelvis.org/js/brunel.2.5.css" charset="utf-8">
//          <link rel="stylesheet" type="text/css" href="https://brunelvis.org/js/sumoselect.css" charset="utf-8">
//          <style>  </style>
//          <div id="controlsIde6900ddb-c001-4789-9359-276f871c7948" class="brunel"/>
// <svg id="visidead2cd59-7fe5-4a1f-9f31-e745af4ac69a" width="500" height="400"></svg>
//
// <script>
// require.config({
//             waitSeconds: 60,
//             paths: {
//                 'd3': '//cdnjs.cloudflare.com/ajax/libs/d3/4.2.1/d3.min',
//                 'topojson' : '//cdnjs.cloudflare.com/ajax/libs/topojson/1.6.20/topojson.min',
//                 'brunel' : 'https://brunelvis.org/js/brunel.2.5.min',
//                 'brunelControls' : 'https://brunelvis.org/js/brunel.controls.2.5.min'
//             },
//
//             shim: {
//                'brunel' : {
//                     exports: 'BrunelD3',
//                     deps: ['d3', 'topojson'],
//                     init: function() {
//                        return {
//                          BrunelD3 : BrunelD3,
//                          BrunelData : BrunelData
//                       }
//                     }
//                 },
//                'brunelControls' : {
//                     exports: 'BrunelEventHandlers',
//                     init: function() {
//                        return {
//                          BrunelEventHandlers: BrunelEventHandlers,
//                          BrunelJQueryControlFactory: BrunelJQueryControlFactory
//                       }
//                     }
//                 }
//
//             }
//
//         });
//
//         require(["d3"], function(d3) {
//         require(["brunel", "brunelControls"], function(brunel, brunelControls) {
//
//             function  BrunelVis(visId) {
//   "use strict";                                                                       // strict mode
//   var datasets = [],                                      // array of datasets for the original data
//       pre = function(d, i) { return d },                         // default pre-process does nothing
//       post = function(d, i) { return d },                       // default post-process does nothing
//       transitionTime = 200,                                        // transition time for animations
//       charts = [],                                                       // the charts in the system
//       vis = d3.select('#' + visId).attr('class', 'brunel');                     // the SVG container
//
//   BrunelD3.addDefinitions(vis);                                   // ensure standard symbols present
//
//   // Define chart #1 in the visualization //////////////////////////////////////////////////////////
//
//   charts[0] = function(parentNode, filterRows) {
//     var geom = BrunelD3.geometry(parentNode || vis.node(), 0, 0, 1, 1, 0, 0, 0, 0),
//       elements = [];                                              // array of elements in this chart
//
//     // Define groups for the chart parts ///////////////////////////////////////////////////////////
//
//     var chart =  vis.append('g').attr('class', 'chart1')
//       .attr('transform','translate(' + geom.chart_left + ',' + geom.chart_top + ')');
//     var overlay = chart.append('g').attr('class', 'element').attr('class', 'overlay');
//     var zoom = d3.zoom().scaleExtent([1/5,5]);
//     var zoomNode = overlay.append('rect').attr('class', 'overlay')
//       .attr('x', geom.inner_left).attr('y', geom.inner_top)
//       .attr('width', geom.inner_rawWidth).attr('height', geom.inner_rawHeight)
//       .style('cursor', 'move').call(zoom)
//       .node();
//     zoomNode.__zoom = d3.zoomIdentity;
//     chart.append('rect').attr('class', 'background').attr('width', geom.chart_right-geom.chart_left).attr('height', geom.chart_bottom-geom.chart_top);
//     var interior = chart.append('g').attr('class', 'interior zoomNone')
//       .attr('transform','translate(' + geom.inner_left + ',' + geom.inner_top + ')')
//       .attr('clip-path', 'url(#clip_visidead2cd59-7fe5-4a1f-9f31-e745af4ac69a_chart1_inner)');
//     interior.append('rect').attr('class', 'inner').attr('width', geom.inner_width).attr('height', geom.inner_height);
//     var gridGroup = interior.append('g').attr('class', 'grid');
//     vis.select('defs').append('clipPath').attr('id', 'clip_visidead2cd59-7fe5-4a1f-9f31-e745af4ac69a_chart1_inner').append('rect')
//       .attr('x', 0).attr('y', 0)
//       .attr('width', geom.inner_rawWidth+1).attr('height', geom.inner_rawHeight+1);
//
//     // Projection //////////////////////////////////////////////////////////////////////////////////
//
//     var base = d3.geoMercator()
//       .translate([geom.inner_width/2, geom.inner_height/2])
//       .scale(Math.min((geom.inner_width-4)/0.5011, (geom.inner_height-4)/0.6884))
//       .center([0.665, 49.7091])
//     function projection(p) {
//         var q = base(p), t = d3.zoomTransform(zoomNode);
//         return q ? [t.k*q[0]+t.x, t.k*q[1]+t.y] : [-9e99,-9e99];
//     };
//     function project_center(v) { return v ? projection([v.c, v.d]) : [-9e99,-9e99] };
//     var path = d3.geoPath().projection(BrunelD3.geoStream(projection));
//     var scale_x = d3.scaleLinear(), scale_y = d3.scaleLinear();
//     var base_scales = [scale_x, scale_y];                           // untransformed original scales
//     zoom.on('zoom', function(t, time) {
//         t = t || d3.event.transform;
//         zoomNode.__zoom = t;
//         interior.attr('class', 'interior ' + BrunelD3.zoomLabel(t.k));;
//         build(time || -1);
//     });
//
//     // Define element #1 ///////////////////////////////////////////////////////////////////////////
//
//     elements[0] = function() {
//       var original, processed,                           // data sets passed in and then transformed
//         element, data,                                 // brunel element information and brunel data
//         selection, merged;                                      // d3 selection and merged selection
//       var elementGroup = interior.append('g').attr('class', 'element1'),
//         main = elementGroup.append('g').attr('class', 'main'),
//         labels = BrunelD3.undoTransform(elementGroup.append('g').attr('class', 'labels').attr('aria-hidden', 'true'), elementGroup);
//
//       function makeData() {
//         original = datasets[0];
//         if (filterRows) original = original.retainRows(filterRows);
//         processed = pre(original, 0);
//         processed = post(processed, 0);
//         var f0 = processed.field('#row'),
//           f1 = processed.field('#selection');
//         var keyFunc = function(d) { return f0.value(d) };
//         data = {
//           $row:         function(d) { return f0.value(d.row) },
//           $selection:   function(d) { return f1.value(d.row) },
//           $row_f:       function(d) { return f0.valueFormatted(d.row) },
//           $selection_f: function(d) { return f1.valueFormatted(d.row) },
//           _split:       function(d) { return 'ALL' },
//           _key:         keyFunc,
//           _rows:        BrunelD3.makeRowsWithKeys(keyFunc, processed.rowCount())
//         };
//       }
//
//       // Build element from data ///////////////////////////////////////////////////////////////////
//
//       function build(transitionMillis) {
//         element = elements[0];
//         // Read in the feature data and call build again when done
//         var features = {
//           'https://brunelvis.org/geo/2.5/med/UnitedKingdom.json': {
//           },
//           'https://brunelvis.org/geo/2.5/med/France.json': {
//           },
//           'https://brunelvis.org/geo/2.5/med/Spain.json': {
//           },
//           'https://brunelvis.org/geo/2.5/med/Germany.json': {
//           }
//         };
//         if (BrunelD3.addFeatures(data, features, null, null, this, transitionMillis)) return;
//         main.attr('class', 'diagram map');
//
//         // Define selection entry operations
//         function initialState(selection) {
//           selection
//             .attr('class', 'element polygon filled')
//             .classed('nondata', function(d) {return !d || d.row == null})
//             .style('pointer-events', 'none')
//         }
//
//         // Define selection

// %%
%%brunel data('raw:A,B;a,b;a,c;a,d;b,c;a,e;e,f') edge key(A, B) + 
         data('raw:I;a;b;c;d;e;f;g') network color(I) key(I) legends(none) style('fill-opacity:1')
// Out:
// <console>:1: error: ';' expected but ',' found.
// raw:A,B;a,b;a,c;a,d;b,c;a,e;e,f
//      ^
// <console>:1: error: ';' expected but ',' found.
// raw:A,B;a,b;a,c;a,d;b,c;a,e;e,f
//          ^
// <console>:1: error: ';' expected but ',' found.
// raw:A,B;a,b;a,c;a,d;b,c;a,e;e,f
//              ^
// <console>:1: error: ';' expected but ',' found.
// raw:A,B;a,b;a,c;a,d;b,c;a,e;e,f
//                  ^
// <console>:1: error: ';' expected but ',' found.
// raw:A,B;a,b;a,c;a,d;b,c;a,e;e,f
//                      ^
// <console>:1: error: ';' expected but ',' found.
// raw:A,B;a,b;a,c;a,d;b,c;a,e;e,f
//                          ^
// <console>:1: error: ';' expected but ',' found.
// raw:A,B;a,b;a,c;a,d;b,c;a,e;e,f
//                              ^
// Magic brunel failed to execute with error:
// compile-time error
